# %%
import pandas as pd

# %%
freedom = pd.read_csv("Resources\human-freedom-index.csv")
footprint = pd.read_csv("Resources\global-eco-footprint.csv")

# %%
freedom=freedom.rename(columns={
"hf_score":"Overall_Score",
"hf_rank":"Overall_Rank",
"hf_quartile":"Overall_Quartile",
"pf_rol":"PF_rol",
"pf_ss_homicide":"PF_SS_Homicide",
"pf_ss_disappearances":"PF_SS_Disappearances",
"pf_ss_women":"PF_SS_Women",
"pf_ss":"PF_SS",
"pf_movement":"PF_Movement",
"pf_religion":"PF_Religion",
"pf_association":"PF_Association",
"pf_expression":"PF_Expression",
"pf_identity":"PF_Identity",
"pf_score":"PF_Score",
"pf_rank":"PF_Rank",
"ef_government":"EF_Govt",
"ef_legal":"EF_Legal",
"ef_money":"EF_Money",
"ef_trade_tariffs":"EF_Trade_Tariffs",
"ef_trade_regulatory":"EF_Trade_Regulatory",
"ef_trade_black":"EF_Trade_Black",
"ef_trade_movement":"EF_Trade_Movement",
"ef_trade":"EF_trade",
"ef_regulation_credit":"EF_Reg_Credit",
"ef_regulation_labor":"EF_Reg_Labor",
"ef_regulation_business":"EF_Reg_Business",
"ef_regulation":"EF_Reg",
"ef_score":"EF_Score",
"ef_rank":"EF_Rank"})

# %%
freedom = freedom.loc[freedom['year']==2016]
freedom = freedom.rename(columns={
    "countries":"Country"
})

# %%
freedom_col = list(freedom)
for col in freedom_col:
    print(f"'{col}',")
# Out:
# 'Unnamed: 0',
# 'year',
# 'ISO_code',
# 'Country',
# 'region',
# 'Overall_Score',
# 'Overall_Rank',
# 'Overall_Quartile',
# 'pf_rol_procedural',
# 'pf_rol_civil',
# 'pf_rol_criminal',
# 'PF_rol',
# 'PF_SS_Homicide',
# 'pf_ss_disappearances_disap',
# 'pf_ss_disappearances_violent',
# 'pf_ss_disappearances_organized',
# 'pf_ss_disappearances_fatalities',
# 'pf_ss_disappearances_injuries',
# 'PF_SS_Disappearances',
# 'pf_ss_women_fgm',
# 'pf_ss_women_missing',
# 'pf_ss_women_inheritance_widows',
# 'pf_ss_women_inheritance_daughters',
# 'pf_ss_women_inheritance',
# 'PF_SS_Women',
# 'PF_SS',
# 'pf_movement_domestic',
# 'pf_movement_foreign',
# 'pf_movement_women',
# 'PF_Movement',
# 'pf_religion_estop_establish',
# 'pf_religion_estop_operate',
# 'pf_religion_estop',
# 'pf_religion_harassment',
# 'pf_religion_restrictions',
# 'PF_Religion',
# 'pf_association_association',
# 'pf_association_assembly',
# 'pf_association_political_establish',
# 'pf_association_political_operate',
# ...

# %%
new_freedom = freedom[['year',
'ISO_code',
'Country',
'region',
'Overall_Score',
'Overall_Rank',
'Overall_Quartile',
'PF_rol',
'PF_SS_Homicide',
'PF_SS_Women',
'PF_SS',
'PF_Movement',
'PF_Religion',
'PF_Association',
'PF_Expression',
'PF_Identity',
'PF_Score',
'PF_Rank',
'EF_Govt',
'EF_Legal',
'EF_Money',
'EF_Trade_Tariffs',
'EF_Trade_Regulatory',
'EF_Trade_Black',
'EF_Trade_Movement',
'EF_trade',
'EF_Reg_Credit',
'EF_Reg_Labor',
'EF_Reg_Business',
'EF_Reg',
'EF_Score',
'EF_Rank',]].copy()
new_freedom.head()
# Out:
#    year ISO_code    Country                         region  Overall_Score  \
# 0  2016      ALB    Albania                 Eastern Europe       7.568140
# 1  2016      DZA    Algeria     Middle East & North Africa       5.135886
# 2  2016      AGO     Angola             Sub-Saharan Africa       5.640662
# 3  2016      ARG  Argentina  Latin America & the Caribbean       6.469848
# 4  2016      ARM    Armenia        Caucasus & Central Asia       7.241402
#
#    Overall_Rank  Overall_Quartile    PF_rol  PF_SS_Homicide  PF_SS_Women  \
# 0          48.0               2.0  5.291752        8.920429     7.500000
# 1         155.0               4.0  3.819566        9.456254     5.833333
# 2         142.0               4.0  3.451814        8.060260     8.333333
# 3         107.0               3.0  5.744791        7.622974    10.000000
# 4          57.0               2.0  5.003205        8.808750     8.333333
#
#     ...     EF_Trade_Regulatory  EF_Trade_Black  EF_Trade_Movement  EF_trade  \
# ...

# %%
footprint.head()
# Out:
#                Country                    Region  Population (millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#   GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 0        $614.66                0.30               0.20              0.08
# 1      $4,534.37                0.78               0.22              0.25
# 2      $5,430.57                0.60               0.16              0.17
# 3      $4,665.91                0.33               0.15              0.12
# 4     $13,205.10                 NaN                NaN               NaN
#
# ...

# %%
ISO_codes = new_freedom[['ISO_code','Country']].copy()
ISO_codes
# Out:
#     ISO_code                 Country
# 0        ALB                 Albania
# 1        DZA                 Algeria
# 2        AGO                  Angola
# 3        ARG               Argentina
# 4        ARM                 Armenia
# 5        AUS               Australia
# 6        AUT                 Austria
# 7        AZE              Azerbaijan
# 8        BHS                 Bahamas
# 9        BHR                 Bahrain
# 10       BGD              Bangladesh
# 11       BRD                Barbados
# 12       BLR                 Belarus
# 13       BEL                 Belgium
# 14       BLZ                  Belize
# 15       BEN                   Benin
# 16       BTN                  Bhutan
# 17       BOL                 Bolivia
# 18       BIH  Bosnia and Herzegovina
# 19       BWA                Botswana
# 20       BRA                  Brazil
# 21       BRN       Brunei Darussalam
# 22       BGR                Bulgaria
# 23       BFA            Burkina Faso
# ...

# %%
footprint = pd.merge(footprint,ISO_codes, how='inner', on='Country')
footprint
# Out:
#                     Country                    Region  Population (millions)  \
# 0                   Albania   Northern/Eastern Europe                  3.160
# 1                   Algeria                    Africa                 38.480
# 2                    Angola                    Africa                 20.820
# 3                 Argentina             Latin America                 41.090
# 4                   Armenia  Middle East/Central Asia                  2.970
# 5                 Australia              Asia-Pacific                 23.050
# 6                   Austria            European Union                  8.460
# 7                Azerbaijan  Middle East/Central Asia                  9.310
# 8                   Bahamas             Latin America                  0.370
# 9                   Bahrain  Middle East/Central Asia                  1.320
# 10               Bangladesh              Asia-Pacific                154.700
# ...

# %%
footprint.set_index('ISO_code')
# Out:
#                          Country                    Region  \
# ISO_code
# ALB                      Albania   Northern/Eastern Europe
# DZA                      Algeria                    Africa
# AGO                       Angola                    Africa
# ARG                    Argentina             Latin America
# ARM                      Armenia  Middle East/Central Asia
# AUS                    Australia              Asia-Pacific
# AUT                      Austria            European Union
# AZE                   Azerbaijan  Middle East/Central Asia
# BHS                      Bahamas             Latin America
# BHR                      Bahrain  Middle East/Central Asia
# BGD                   Bangladesh              Asia-Pacific
# BRD                     Barbados             Latin America
# BLR                      Belarus   Northern/Eastern Europe
# BEL                      Belgium            European Union
# BEN                        Benin                    Africa
# ...
